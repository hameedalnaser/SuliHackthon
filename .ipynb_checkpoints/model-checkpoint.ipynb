# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('data/dataset.csv')
df
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 1    213   7.5  338  7.62  0.75  1.06  25.40  0.30  0.86  1.54   2.89  2.29
# 2    163   9.6  718  7.59  0.51  1.11  14.30  0.30  0.86  1.57   2.70  2.03
# 3    157   6.8  475  7.64  0.58  0.94  26.00  0.34  0.54  1.53   2.65  1.82
# 4    270   9.9  444  7.63  0.40  0.86  11.80  0.25  0.76  1.69   2.43  2.26
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 875  351  10.7  623  7.96  0.51  0.29   7.24  0.36  4.69  0.69  11.03  0.69
# 876  264   9.0  486  7.24  0.47  0.10   3.92  0.35  8.26  0.45   7.98  0.40
# 877  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 878  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 879  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
#
#      Output
# 0         0
# 1         0
# 2         0
# ...

# %%
#output
# 0 means very good soil for farming
# 1 good soil for farming
# 2 not that good for farming
df.tail(10)
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 870  345  13.6  444  7.85  0.38  0.10   6.33  0.35  8.54  1.02   9.64  0.65
# 871  314  14.9  359  7.04  0.43  0.68   5.13  0.17  6.11  0.88   3.74  0.21
# 872  333  13.8  401  7.62  0.51  0.49   3.92  0.26  3.05  1.03   9.05  0.34
# 873  339   8.3  380  7.67  0.32  0.88   5.13  0.33  7.96  1.65  12.47  0.44
# 874  326  10.3  507  7.88  0.71  0.39   8.75  0.21  8.63  2.01   8.63  0.32
# 875  351  10.7  623  7.96  0.51  0.29   7.24  0.36  4.69  0.69  11.03  0.69
# 876  264   9.0  486  7.24  0.47  0.10   3.92  0.35  8.26  0.45   7.98  0.40
# 877  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 878  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 879  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
#
#      Output
# 870       2
# 871       2
# 872       2
# 873       1
# 874       1
# 875       1
# 876       1
# 877       1
# ...

# %%
df['Output'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
x = df.drop('Output', axis=1)

# %%
y=df['Output']

# %%
#Transforming the data to make it between 0 and 1 so that the ML algorithm works better
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(x)
x = scaler.transform(x)
x
# Out:
# array([[0.35013263, 0.04668305, 0.62671233, ..., 0.23208191, 0.27840725,
#         0.01811594],
#        [0.54907162, 0.03767404, 0.37328767, ..., 0.49488055, 0.08999676,
#         0.80797101],
#        [0.41644562, 0.05487305, 0.80707763, ..., 0.50511945, 0.0838459 ,
#         0.71376812],
#        ...,
#        [0.71618037, 0.05159705, 0.40981735, ..., 0.18430034, 0.2062156 ,
#         0.0942029 ],
#        [0.83289125, 0.08927109, 0.43378995, ..., 0.31740614, 0.42538038,
#         0.17028986],
#        [0.68435013, 0.06060606, 0.52968037, ..., 0.60750853, 0.34056329,
#         0.20652174]])

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# features = df[['N', 'P', 'K', 'pH', 'EC', 'OC', 'S', 'Zn', 'Fe', 'Cu', 'Mn', 'B']]
features = df[['N', 'P', 'K', 'pH']]
target = df['Output']
#features = df[['temperature', 'humidity', 'ph', 'rainfall']]
labels = df['Output']
acc = []
model = []

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(features,target,test_size = 0.2,random_state =2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
RF = RandomForestClassifier(n_estimators=20, random_state=0)
RF.fit(Xtrain,Ytrain)

predicted_values = RF.predict(Xtest)

x = metrics.accuracy_score(Ytest, predicted_values)
acc.append(x)
model.append('RF')
print("RF's Accuracy is: ", x)

print(classification_report(Ytest,predicted_values))
model
# Out:
# RF's Accuracy is:  0.9431818181818182
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96        78
#            1       0.95      0.96      0.95        93
#            2       0.67      0.40      0.50         5
#
#     accuracy                           0.94       176
#    macro avg       0.85      0.77      0.80       176
# weighted avg       0.94      0.94      0.94       176
# ['RF']

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(RF,features,target,cv=5)
score
# Out:
# array([0.88636364, 0.9375    , 0.875     , 0.92045455, 0.80113636])

# %%
plt.figure(figsize=[10,1],dpi = 100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')
# Out:
# <Axes: title={'center': 'Accuracy Comparison'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
accuracy_models = dict(zip(model, acc))
for k, v in accuracy_models.items():
    print (k, '-->', v)
# Out:
# RF --> 0.9431818181818182

# %%
data = np.array([[138, 8.6, 560, 7.46]])
#                   0.62, 0.70, 5.90, 0.24, 0.31, 0.77, 8.71, 0.11]])
prediction = RF.predict(data)
print(prediction)
# Out:
# [0]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
data = np.array([[320, 13.8, 391, 7.38]])
#                   0.65, 1.07, 5.43, 0.58, 4.58, 1.7, 13.1, 0.23]])
prediction = RF.predict(data)
print(prediction)
# Out:
# [2]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle
RF_pkl_filename = './RFmodel.pkl'
RF_Model_pkl = open(RF_pkl_filename, 'wb')
pickle.dump(RF, RF_Model_pkl)
RF_Model_pkl.close()

# %%
# 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
# chatgpt key

# %%
import openai
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import openai
#
# ModuleNotFoundError: No module named 'openai'
